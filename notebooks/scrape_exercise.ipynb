# %%
import re, json
from urllib.parse import urljoin, urlparse, urldefrag
from bs4 import BeautifulSoup
from playwright.async_api import async_playwright

BASE = "https://exrx.net"

SPACE = re.compile(r"\s+")
def norm(t: str) -> str:
    return SPACE.sub(" ", (t or "").strip())

def last_path_key(u: str) -> str:
    p = urlparse(u)
    return p.path.rstrip("/").split("/")[-1]  # es. ShouldWt

# Mappa stabile: chiave nel path -> nome macro umano
PATH2MACRO = {
    "NeckWt": "Neck",
    "ShouldWt": "Shoulders",
    "ArmWt": "Upper Arms",
    "ForeArmWt": "Forearms",
    "BackWt": "Back",
    "ChestWt": "Chest",
    "WaistWt": "Waist",
    "HipsWt": "Hips",
    "ThighWt": "Thighs",
    "CalfWt": "Calves",
    # Se in futuro userai “Other Exercises”, aggiungi qui le chiavi relative
}
MACRO_NAMES = set(PATH2MACRO.values())

# %%
async def fetch_html(url: str) -> str:
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        ctx = await browser.new_context(
            user_agent=("Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                        "AppleWebKit/537.36 (KHTML, like Gecko) "
                        "Chrome/124.0.0.0 Safari/537.36")
        )
        page = await ctx.new_page()
        await page.goto(url, wait_until="domcontentloaded")
        await page.wait_for_timeout(1200)  # piccolo respiro per WAF/JS
        html = await page.content()
        await ctx.close(); await browser.close()
        return html

# %%
async def parse_macro_categories(dir_url=f"{BASE}/Lists/Directory"):
    html = await fetch_html(dir_url)
    soup = BeautifulSoup(html, "lxml")

    # raccogli tutti i link che portano a /Lists/ExList/<Key>
    candidates = []
    for a in soup.select("a[href]"):
        href = a.get("href");
        if not href:
            continue
        absu = urljoin(dir_url, href)
        if "/Lists/ExList/" not in absu:
            continue
        key = last_path_key(absu)              # es. ShouldWt
        url_clean = urldefrag(absu)[0]         # senza #fragment
        txt = norm(a.get_text())               # etichetta mostrata per quel link
        candidates.append((key, url_clean, txt))

    # collassa per chiave (Key) -> scegli un nome macro “migliore”
    macros = {}
    for key, url_clean, txt in candidates:
        # se la chiave è mappata, usa il nome canonico; altrimenti prova il testo del link
        canonical = PATH2MACRO.get(key)
        display = canonical or txt
        # preferisci un nome che appartenga all’elenco canonico se appare tra i link
        if key not in macros:
            macros[key] = {"macro_key": key, "macro_name": display, "list_url": url_clean}
        else:
            # se non avevamo un nome canonico e ora vediamo un link con nome “ufficiale”, aggiorna
            if macros[key]["macro_name"] not in MACRO_NAMES and display in MACRO_NAMES:
                macros[key]["macro_name"] = display
            # assicura che l’URL sia quello senza fragment
            macros[key]["list_url"] = url_clean

    # ordina alfabeticamente per nome macro
    out = sorted(macros.values(), key=lambda d: d["macro_name"].lower())
    return out

# %%
macros = await parse_macro_categories()
print("Macrocategorie trovate:", len(macros))
for m in macros:
    print(f"- {m['macro_name']:12s} → {m['list_url']}")
# Out:
# Macrocategorie trovate: 10
# - Back         → https://exrx.net/Lists/ExList/BackWt
# - Calves       → https://exrx.net/Lists/ExList/CalfWt
# - Chest        → https://exrx.net/Lists/ExList/ChestWt
# - Forearms     → https://exrx.net/Lists/ExList/ForeArmWt
# - Hips         → https://exrx.net/Lists/ExList/HipsWt
# - Neck         → https://exrx.net/Lists/ExList/NeckWt
# - Shoulders    → https://exrx.net/Lists/ExList/ShouldWt
# - Thighs       → https://exrx.net/Lists/ExList/ThighWt
# - Upper Arms   → https://exrx.net/Lists/ExList/ArmWt
# - Waist        → https://exrx.net/Lists/ExList/WaistWt

# %%
import re, json
from urllib.parse import urljoin, urldefrag
from bs4 import BeautifulSoup

SPACE = re.compile(r"\s+")
def norm(t: str) -> str:
    return SPACE.sub(" ", (t or "").strip())

IMPLE_MAP = {
    "barbell": "barbell",
    "body weight": "bodyweight",
    "bodyweight": "bodyweight",
    "dumbbell": "dumbbell",
    "kettlebell": "kettlebell",
    "cable": "cable",
    "lever": "lever",
    "machine": "machine",
    "smith": "smith machine",
    "smith machine": "smith machine",
    "suspended": "suspended",
    "self-assisted": "self-assisted",
    "stretch": "stretch",
    "dynamic stretch": "dynamic stretch",
    "plyometrics": "plyometrics",
    "band": "band",
    "medicine ball": "medicine ball",
    "sandbag": "sandbag",
    "sled": "sled",
    "trap bar": "trap bar",
    "trx": "suspended",
}
def norm_implement(label: str) -> str:
    l = norm(label).lower()
    if l.startswith("lever"):  # lever (selectorized / plate loaded)
        return "lever"
    for k,v in IMPLE_MAP.items():
        if k in l:
            return v
    return l or "unknown"

async def parse_macro_page(list_url: str, macro_name: str):
    html = await fetch_html(list_url)
    soup = BeautifulSoup(html, "lxml")

    SPACE = re.compile(r"\s+")
    def norm(t: str) -> str:
        return SPACE.sub(" ", (t or "").strip())

    IMPLEMENT_HEADINGS = {
        "barbell","body weight","bodyweight","cable","dumbbell","kettlebell",
        "lever","machine","smith","smith machine","suspended","self-assisted",
        "stretch","dynamic stretch","plyometrics","band","medicine ball","sandbag",
        "sled","trap bar","trx"
    }
    def is_implement_heading(text: str) -> bool:
        t = norm(text).lower()
        if t.startswith("lever"):  # lever (selectorized/plate loaded)
            return True
        return any(k == t or k in t for k in IMPLEMENT_HEADINGS)

    def norm_impl(label: str) -> str:
        l = norm(label).lower()
        if l.startswith("lever"):  return "lever"
        if "smith" in l:           return "smith machine"
        if "body weight" in l or l == "bodyweight": return "bodyweight"
        for k in IMPLEMENT_HEADINGS:
            if k in l: return k
        return l or "unknown"

    def anchor(li):
        a = li.find("a", href=True)
        if not a:
            return None, None
        return norm(a.get_text()), urldefrag(urljoin(list_url, a["href"]))[0]

    def direct_text(el) -> str:
        if el is None: return ""
        txts = [t for t in el.find_all(string=True, recursive=False)]
        return norm(" ".join(txts))

    records = []
    current_micro = None
    current_impl  = None
    processed_uls = set()

    def emit(name, url, micro, impl):
        if not name or not url:
            return
        records.append({
            "macro_group": macro_name,
            "micro_group": micro or "",
            "implement": impl or "",
            "exercise_name": name,
            "exercise_url": url,
            "list_url": list_url,
        })

    def walk_variants(parent_li, base_name, base_url, micro, impl):
        """
        Scorre le varianti annidate sotto parent_li:
        - per ogni li child con anchor → nome composto "base — child"
        - se un child ha a sua volta sub-ul, prosegue ricorsivamente
        """
        ul = parent_li.find("ul")
        if not ul:
            return
        if id(ul) in processed_uls:
            return
        processed_uls.add(id(ul))

        for child in ul.find_all("li", recursive=False):
            vname, vurl = anchor(child)
            if vname and vurl:
                composed = f"{base_name} — {vname}"
                emit(composed, vurl, micro, impl)
            # ricorsione per livelli più profondi
            if child.find("ul"):
                walk_variants(child, base_name if not vname else composed, vurl or base_url, micro, impl)

    # scan sequenziale
    for node in soup.find_all(["h1","h2","h3","h4","strong","ul","li"]):
        tag  = node.name.lower()
        text = norm(node.get_text())

        # micro (titoli muscolari)
        if tag in ("h1","h2","h3") and text:
            if any(w in text.lower() for w in (
                "deltoid","quadriceps","hamstrings","gluteus","pectoralis","abdominis",
                "obliques","trapezius","rhomboids","erector","calves","soleus",
                "gastrocnemius","forearm","biceps","triceps","back","hip","waist","neck"
            )):
                current_micro = text
                current_impl  = None
                continue

        # implement come header
        if tag in ("h3","h4","strong") and text and is_implement_heading(text):
            current_impl = norm_impl(text)
            continue

        # implement come LI contenitore: <li>Barbell<ul>...</ul></li>
        if tag == "li" and node.find("ul"):
            impl_label = direct_text(node)
            if is_implement_heading(impl_label):
                current_impl = norm_impl(impl_label)
                # ogni li *figlio* di questo ul è un esercizio o una sottocategoria
                ul = node.find("ul")
                if id(ul) not in processed_uls:
                    processed_uls.add(id(ul))
                    for li in ul.find_all("li", recursive=False):
                        name, url = anchor(li)
                        if name and url:
                            emit(name, url, current_micro, current_impl)
                            # gestisci varianti sotto questo li (se presenti)
                            if li.find("ul"):
                                walk_variants(li, name, url, current_micro, current_impl)
                continue

        # UL “libero” sotto un header implement
        if tag == "ul" and current_micro:
            if node.find_parent("li") is not None:
                continue
            prev_hdr = node.find_previous(lambda t: t.name in ("h3","h4","strong","h2","h1"))
            if not (prev_hdr and is_implement_heading(prev_hdr.get_text())):
                continue
            current_impl = norm_impl(prev_hdr.get_text())
            if id(node) in processed_uls:
                continue
            processed_uls.add(id(node))
            for li in node.find_all("li", recursive=False):
                name, url = anchor(li)
                if name and url:
                    emit(name, url, current_micro, current_impl)
                    if li.find("ul"):
                        walk_variants(li, name, url, current_micro, current_impl)

    # dedup finale per (url, micro, implement, name)
    seen, out = set(), []
    for r in records:
        key = (r["exercise_url"], r["micro_group"], r["implement"], r["exercise_name"])
        if key in seen:
            continue
        seen.add(key); out.append(r)
    return out

    # dedup
    seen, out = set(), []
    for r in records:
        key = (r["exercise_url"], r["micro_group"], r["implement"])
        if key in seen:
            continue
        seen.add(key); out.append(r)
    return out

    # Dedup
    seen, out = set(), []
    for r in records:
        key = (r["exercise_url"], r["micro_group"], r["implement"])
        if key in seen:
            continue
        seen.add(key); out.append(r)
    return out

    # dedup
    seen, out = set(), []
    for r in records:
        key = (r["exercise_url"], r["micro_group"], r["implement"])
        if key in seen:
            continue
        seen.add(key); out.append(r)
    return out

# %%
# esempio: Shoulders
macros = await parse_macro_categories()
shoulders = next(m for m in macros if m["macro_name"]=="Shoulders")
recs = await parse_macro_page(shoulders["list_url"], macro_name=shoulders["macro_name"])
print("Esercizi estratti (Shoulders):", len(recs))
for r in recs[:15]:
    print(f"- [{r['micro_group']}] {r['implement'] or 'unknown'} | {r['exercise_name']} → {r['exercise_url']}")
# Out:
# Esercizi estratti (Shoulders): 70
# - [Anterior Deltoid] barbell | Front Raise → https://exrx.net/WeightExercises/DeltoidAnterior/BBFrontRaise
# - [Anterior Deltoid] barbell | Military Press → https://exrx.net/WeightExercises/DeltoidAnterior/BBMilitaryPress
# - [Anterior Deltoid] barbell | Military Press — Seated → https://exrx.net/WeightExercises/DeltoidAnterior/BBSeatedMilitaryPress
# - [Anterior Deltoid] cable | Front Raise → https://exrx.net/WeightExercises/DeltoidAnterior/CBSeatedFrontRaise
# - [Anterior Deltoid] cable | Front Raise — Alternating → https://exrx.net/WeightExercises/DeltoidAnterior/CBAlternatingFrontRaise
# - [Anterior Deltoid] cable | Front Raise — One Arm → https://exrx.net/WeightExercises/DeltoidAnterior/CBFrontRaise
# - [Anterior Deltoid] cable | Shoulder Press → https://exrx.net/WeightExercises/DeltoidAnterior/CBStandingShoulderPress
# - [Anterior Deltoid] cable | Shoulder Press — Seated → https://exrx.net/WeightExercises/DeltoidAnterior/CBShoulderPress
# - [Anterior Deltoid] dumbbell | Arnold Press → https://exrx.net/WeightExercises/DeltoidAnterior/DBArnoldPress
# - [Anterior Deltoid] dumbbell | Front Raise → https://exrx.net/WeightExercises/DeltoidAnterior/DBFrontRaise
# - [Anterior Deltoid] dumbbell | Front Raise — Alternating → https://exrx.net/WeightExercises/DeltoidAnterior/DBAlternatingFrontRaise
# - [Anterior Deltoid] dumbbell | Shoulder Press → https://exrx.net/WeightExercises/DeltoidAnterior/DBShoulderPress
# - [Anterior Deltoid] dumbbell | Shoulder Press — One Arm → https://exrx.net/WeightExercises/DeltoidAnterior/DBOneArmShoulderPress
# - [Anterior Deltoid] lever | Military Press → https://exrx.net/WeightExercises/DeltoidAnterior/LVMilitaryPressH
# - [Anterior Deltoid] lever | Reclined Shoulder Press → https://exrx.net/WeightExercises/DeltoidAnterior/LVReclinedShoulderPressPL

# %%
import asyncio, time

async def crawl_all_macros(delay_sec: float = 0.8, limit: int | None = None):
    macros = await parse_macro_categories()
    if limit:
        macros = macros[:limit]

    all_rows = []
    per_macro_counts = {}

    for i, m in enumerate(macros, 1):
        t0 = time.time()
        try:
            rows = await parse_macro_page(m["list_url"], macro_name=m["macro_name"])
        except Exception as e:
            print(f"[{i}/{len(macros)}] ERRORE {m['macro_name']}: {e}")
            rows = []
        all_rows.extend(rows)
        per_macro_counts[m["macro_name"]] = len(rows)

        dt = time.time() - t0
        # rate limit gentile
        if dt < delay_sec:
            await asyncio.sleep(delay_sec - dt)

        print(f"[{i}/{len(macros)}] {m['macro_name']:<12} → {len(rows):3d} righe (tot {len(all_rows)})")

    return macros, all_rows, per_macro_counts

# ESEGUI (puoi iniziare con limit=3 per test)
macros, rows, per_macro = await crawl_all_macros(delay_sec=0.8, limit=None)
print("\nTot righe:", len(rows))
print("Per macro:", per_macro)
print("Esempio:", rows[:3])
# Out:
# [1/10] Back         → 109 righe (tot 109)
# [2/10] Calves       →  59 righe (tot 168)
# [3/10] Chest        →  72 righe (tot 240)
# [4/10] Forearms     →  28 righe (tot 268)
# [5/10] Hips         → 148 righe (tot 416)
# [6/10] Neck         →  17 righe (tot 433)
# [7/10] Shoulders    →  70 righe (tot 503)
# [8/10] Thighs       → 125 righe (tot 628)
# [9/10] Upper Arms   →  60 righe (tot 688)
# [10/10] Waist        → 101 righe (tot 789)
#
# Tot righe: 789
# Per macro: {'Back': 109, 'Calves': 59, 'Chest': 72, 'Forearms': 28, 'Hips': 148, 'Neck': 17, 'Shoulders': 70, 'Thighs': 125, 'Upper Arms': 60, 'Waist': 101}
# Esempio: [{'macro_group': 'Back', 'micro_group': 'General Back', 'implement': 'barbell', 'exercise_name': 'Bent-over Row', 'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/BBBentOverRow', 'list_url': 'https://exrx.net/Lists/ExList/BackWt'}, {'macro_group': 'Back', 'micro_group': 'General Back', 'implement': 'barbell', 'exercise_name': 'Bent-over Row — Underhand', 'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/BBUnderhandBentOverRow', 'list_url': 'https://exrx.net/Lists/ExList/BackWt'}, {'macro_group': 'Back', 'micro_group': 'General Back', 'implement': 'cable', 'exercise_name': 'One Arm Bent-over Row', 'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/CBOneArmBentoverRow', 'list_url': 'https://exrx.net/Lists/ExList/BackWt'}]

# %%
from collections import defaultdict

def build_catalog(rows: list[dict]) -> dict:
    """
    Collassa le righe (macro,micro,implement,exercise_name,exercise_url)
    in un indice per exercise_url con:
      - name (preferisce il più lungo/descrittivo)
      - implements (set)
      - macro_groups (set)
      - micro_groups (set)
      - variants_by_impl (implement -> set di nomi completi)
      - list_urls (set)
    """
    cat = {}
    for r in rows:
        url = r["exercise_url"]
        name = r["exercise_name"]
        impl = r["implement"] or ""
        micro = r["micro_group"] or ""
        macro = r["macro_group"] or ""
        lst  = r["list_url"]

        doc = cat.get(url, {
            "name": name,
            "exercise_url": url,
            "implements": set(),
            "macro_groups": set(),
            "micro_groups": set(),
            "variants_by_impl": defaultdict(set),
            "list_urls": set(),
        })

        # tieni il nome più “ricco”
        if len(name) > len(doc["name"]):
            doc["name"] = name

        if impl:
            doc["implements"].add(impl)
            doc["variants_by_impl"][impl].add(name)
        else:
            doc["variants_by_impl"]["unknown"].add(name)

        if macro: doc["macro_groups"].add(macro)
        if micro: doc["micro_groups"].add(micro)
        if lst:   doc["list_urls"].add(lst)

        cat[url] = doc

    # set → list ordinata
    for d in cat.values():
        d["implements"]    = sorted(d["implements"])
        d["macro_groups"]  = sorted(d["macro_groups"])
        d["micro_groups"]  = sorted(d["micro_groups"])
        d["list_urls"]     = sorted(d["list_urls"])
        d["variants_by_impl"] = {k: sorted(v) for k, v in d["variants_by_impl"].items()}
    return cat

catalog = build_catalog(rows)
print("Esercizi unici:", len(catalog))
# stampa 3 esempi
for i, (u, d) in enumerate(catalog.items()):
    if i >= 3: break
    print("\nURL:", u)
    print("  name:         ", d["name"])
    print("  implements:   ", d["implements"])
    print("  macro_groups: ", d["macro_groups"])
    print("  micro_groups: ", d["micro_groups"])
    print("  variants_by_impl sample:", {k: v[:3] for k,v in d["variants_by_impl"].items()})
# Out:
# Esercizi unici: 745
#
# URL: https://exrx.net/WeightExercises/BackGeneral/BBBentOverRow
#   name:          Bent-over Row
#   implements:    ['barbell']
#   macro_groups:  ['Back']
#   micro_groups:  ['General Back']
#   variants_by_impl sample: {'barbell': ['Bent-over Row']}
#
# URL: https://exrx.net/WeightExercises/BackGeneral/BBUnderhandBentOverRow
#   name:          Bent-over Row — Underhand
#   implements:    ['barbell']
#   macro_groups:  ['Back']
#   micro_groups:  ['General Back']
#   variants_by_impl sample: {'barbell': ['Bent-over Row — Underhand']}
#
# URL: https://exrx.net/WeightExercises/BackGeneral/CBOneArmBentoverRow
#   name:          One Arm Bent-over Row
#   implements:    ['cable']
#   macro_groups:  ['Back']
#   micro_groups:  ['General Back']
#   variants_by_impl sample: {'cable': ['One Arm Bent-over Row']}

# %%
catalog
# Out:
# {'https://exrx.net/WeightExercises/BackGeneral/BBBentOverRow': {'name': 'Bent-over Row',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/BBBentOverRow',
#   'implements': ['barbell'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'barbell': ['Bent-over Row']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/BBUnderhandBentOverRow': {'name': 'Bent-over Row — Underhand',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/BBUnderhandBentOverRow',
#   'implements': ['barbell'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'barbell': ['Bent-over Row — Underhand']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/CBOneArmBentoverRow': {'name': 'One Arm Bent-over Row',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/CBOneArmBentoverRow',
#   'implements': ['cable'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'cable': ['One Arm Bent-over Row']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/CBOneArmStrBackHighRow': {'name': 'One Arm Straight Back Seated High Row — One Arm Straight Back Seated High Row',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/CBOneArmStrBackHighRow',
#   'implements': ['cable'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'cable': ['One Arm Straight Back Seated High Row',
#     'One Arm Straight Back Seated High Row — One Arm Straight Back Seated High Row']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/CBSeatedRow': {'name': 'One Arm Straight Back Seated High Row — Seated Row',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/CBSeatedRow',
#   'implements': ['cable'],
#   'macro_groups': ['Back', 'Waist'],
#   'micro_groups': ['Erector Spinae', 'General Back'],
#   'variants_by_impl': {'cable': ['One Arm Straight Back Seated High Row — Seated Row',
#     'Seated Row']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt',
#    'https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/CBStraightBackSeatedRow': {'name': 'One Arm Straight Back Seated High Row — Seated Row — Straight Back',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/CBStraightBackSeatedRow',
#   'implements': ['cable'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'cable': ['One Arm Straight Back Seated High Row — Seated Row — Straight Back']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/CBWideGripSeatedRow': {'name': 'One Arm Straight Back Seated High Row — Seated Wide Grip Row',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/CBWideGripSeatedRow',
#   'implements': ['cable'],
#   'macro_groups': ['Back', 'Waist'],
#   'micro_groups': ['Erector Spinae', 'General Back'],
#   'variants_by_impl': {'cable': ['One Arm Straight Back Seated High Row — Seated Wide Grip Row',
#     'Seated Row — Wide Grip']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt',
#    'https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/CBWideGripStrBackSeatedRow': {'name': 'One Arm Straight Back Seated High Row — Seated Wide Grip Row — Straight Back',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/CBWideGripStrBackSeatedRow',
#   'implements': ['cable'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'cable': ['One Arm Straight Back Seated High Row — Seated Wide Grip Row — Straight Back']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/DBBentOverRow': {'name': 'Bent-over Row',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/DBBentOverRow',
#   'implements': ['dumbbell'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'dumbbell': ['Bent-over Row']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/DBLyingRow': {'name': 'Lying Row',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/DBLyingRow',
#   'implements': ['dumbbell'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'dumbbell': ['Lying Row']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/LVNeutralGripInclineRowPL': {'name': 'Incline Row Neutral Grip',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/LVNeutralGripInclineRowPL',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'lever': ['Incline Row Neutral Grip']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/LVWideGripInclineRowPL': {'name': 'Incline Row Wide Grip',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/LVWideGripInclineRowPL',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'lever': ['Incline Row Wide Grip']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/LVNarrowGripSeatedRowH': {'name': 'Narrow Grip — Narrow Grip',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/LVNarrowGripSeatedRowH',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'lever': ['Narrow Grip', 'Narrow Grip — Narrow Grip']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/LVWideGripSeatedRowH': {'name': 'Narrow Grip — Wide Grip',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/LVWideGripSeatedRowH',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'lever': ['Narrow Grip — Wide Grip']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/LVWideLowGripSeatedRowH': {'name': 'Narrow Grip — Wide Grip — Low Bar',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/LVWideLowGripSeatedRowH',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'lever': ['Narrow Grip — Wide Grip — Low Bar']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/LVSeatedLowRow': {'name': 'Seated Low Row — Seated Low Row',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/LVSeatedLowRow',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'lever': ['Seated Low Row',
#     'Seated Low Row — Seated Low Row']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/LVSeatedHighRowPL': {'name': 'Seated Low Row — Seated High Row',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/LVSeatedHighRowPL',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'lever': ['Seated Low Row — Seated High Row']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/LVTBarRow': {'name': 'T-bar Row',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/LVTBarRow',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'lever': ['T-bar Row']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/LVCloseGripTBarRow': {'name': 'T-bar Row — Close grip',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/LVCloseGripTBarRow',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'lever': ['T-bar Row — Close grip']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/LVSeatedHighRow': {'name': 'Seated High Row',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/LVSeatedHighRow',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'lever': ['Seated High Row']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/LVSeatedRow': {'name': 'Seated Row',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/LVSeatedRow',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'lever': ['Seated Row']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/LVWideGripSeatedRow': {'name': 'Seated Row — Wide Grip',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/LVWideGripSeatedRow',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'lever': ['Seated Row — Wide Grip']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/LVSeatedRowNoPad': {'name': 'Seated Row (no chest pad)',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/LVSeatedRowNoPad',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'lever': ['Seated Row (no chest pad)']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/LVStraightBackSeatedRowNoPad': {'name': 'Seated Row (no chest pad) — Straight Back',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/LVStraightBackSeatedRowNoPad',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'lever': ['Seated Row (no chest pad) — Straight Back']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/LVSeatedUnderhandRow': {'name': 'Underhand Seated Row',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/LVSeatedUnderhandRow',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'lever': ['Underhand Seated Row']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/SMBentOverRow': {'name': 'Bent-over Row',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/SMBentOverRow',
#   'implements': ['smith machine'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'smith machine': ['Bent-over Row']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/BWSupineRow': {'name': 'Inverted Row',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/BWSupineRow',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'bodyweight': ['Inverted Row']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/BWSupineRowFeetElevated': {'name': 'Inverted Row — Feet Elevated',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/BWSupineRowFeetElevated',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'bodyweight': ['Inverted Row — Feet Elevated']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/BWSupineRowHigh': {'name': 'Inverted Row — High Bar',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/BWSupineRowHigh',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'bodyweight': ['Inverted Row — High Bar']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/STInvertedRow': {'name': 'Inverted Row',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/STInvertedRow',
#   'implements': ['suspended'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'suspended': ['Inverted Row']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/STRow': {'name': 'Row',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/STRow',
#   'implements': ['suspended'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'suspended': ['Row']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/STOneArmRow': {'name': 'Row — One Arm',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/STOneArmRow',
#   'implements': ['suspended'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'suspended': ['Row — One Arm']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/Stretches/BackGeneral/FixedBar': {'name': 'Fixed Bar',
#   'exercise_url': 'https://exrx.net/Stretches/BackGeneral/FixedBar',
#   'implements': ['stretch'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'stretch': ['Fixed Bar']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/Stretches/BackGeneral/PCCrossHand': {'name': 'Lever',
#   'exercise_url': 'https://exrx.net/Stretches/BackGeneral/PCCrossHand',
#   'implements': ['stretch'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'stretch': ['Lever']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/BWUnderhandSupineRow': {'name': 'Underhand Inverted Row',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/BWUnderhandSupineRow',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Back', 'Upper Arms'],
#   'micro_groups': ['Biceps Brachii', 'General Back'],
#   'variants_by_impl': {'bodyweight': ['Inverted Biceps Row',
#     'Underhand Inverted Row']},
#   'list_urls': ['https://exrx.net/Lists/ExList/ArmWt',
#    'https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/BackGeneral/BWUnderhandSupineRowHigh': {'name': 'Underhand Inverted Row — High Bar',
#   'exercise_url': 'https://exrx.net/WeightExercises/BackGeneral/BWUnderhandSupineRowHigh',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'bodyweight': ['Underhand Inverted Row — High Bar']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/AsUnderhandChinup': {'name': 'Chin-up',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/AsUnderhandChinup',
#   'implements': ['machine'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'machine': ['Chin-up']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/AsPullupOpenKneeling': {'name': 'Pull-up (open-centered bar)',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/AsPullupOpenKneeling',
#   'implements': ['machine'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'machine': ['Pull-up (open-centered bar)']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/AsPullupOpen': {'name': 'Pull-up (open-centered bar) — Standing',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/AsPullupOpen',
#   'implements': ['machine'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'machine': ['Pull-up (open-centered bar) — Standing']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/AsCloseGripChinupKneeling': {'name': 'Parallel Close Grip Pull-up',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/AsCloseGripChinupKneeling',
#   'implements': ['machine'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'machine': ['Parallel Close Grip Pull-up']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/BBPullover': {'name': 'Pullover',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/BBPullover',
#   'implements': ['barbell'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'barbell': ['Pullover']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/CBBentoverPullover': {'name': 'Bent-over Pullover',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/CBBentoverPullover',
#   'implements': ['cable'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'cable': ['Bent-over Pullover']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/CBCloseGripPulldown': {'name': 'Close Grip Pulldown',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/CBCloseGripPulldown',
#   'implements': ['cable'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'cable': ['Close Grip Pulldown']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/CBFrontPulldown': {'name': 'Pulldown',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/CBFrontPulldown',
#   'implements': ['cable'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'cable': ['Pulldown']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/CBParallelGripPulldown': {'name': 'Pulldown — Parallel Grip Pulldown',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/CBParallelGripPulldown',
#   'implements': ['cable'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'cable': ['Pulldown — Parallel Grip Pulldown']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/CBUnderhandChinup': {'name': 'Chinup — Chinup',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/CBUnderhandChinup',
#   'implements': ['cable'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'cable': ['Chinup', 'Chinup — Chinup']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/CBParallelCloseGripChinup': {'name': 'Chinup — Parallel Close Grip Pull-up',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/CBParallelCloseGripChinup',
#   'implements': ['cable'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'cable': ['Chinup — Parallel Close Grip Pull-up']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/CBParallelGripChinup': {'name': 'Chinup — Parallel Grip Pull-up',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/CBParallelGripChinup',
#   'implements': ['cable'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'cable': ['Chinup — Parallel Grip Pull-up']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/CBPullup': {'name': 'Chinup — Pull-up',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/CBPullup',
#   'implements': ['cable'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'cable': ['Chinup — Pull-up']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/CBUnderhandPulldown': {'name': 'Underhand Pulldown',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/CBUnderhandPulldown',
#   'implements': ['cable'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'cable': ['Underhand Pulldown']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/LVPulldownH': {'name': 'Pulldown',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/LVPulldownH',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'lever': ['Pulldown']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/LVUnderhandPulldownH': {'name': 'Underhand Pulldown',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/LVUnderhandPulldownH',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'lever': ['Underhand Pulldown']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/LVCloseGripPulldown': {'name': 'Close Grip Pulldown',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/LVCloseGripPulldown',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'lever': ['Close Grip Pulldown']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/LVFrontPulldown': {'name': 'Front Pulldown',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/LVFrontPulldown',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'lever': ['Front Pulldown']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/LVPulldown': {'name': 'Pulldown',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/LVPulldown',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'lever': ['Pulldown']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/LVPullover': {'name': 'Pullover',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/LVPullover',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'lever': ['Pullover']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/ASArcherPullupBand': {'name': 'Archer Pull-up',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/ASArcherPullupBand',
#   'implements': ['band'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'band': ['Archer Pull-up']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/ASChinupBand': {'name': 'Chin-up',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/ASChinupBand',
#   'implements': ['band'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'band': ['Chin-up']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/ASPullupBand': {'name': 'Pull-up',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/ASPullupBand',
#   'implements': ['band'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'band': ['Pull-up']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/ASParallelGripPullupBand': {'name': 'Pull-up — Parallel Grip',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/ASParallelGripPullupBand',
#   'implements': ['band'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'band': ['Pull-up — Parallel Grip']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/BWArcherPullup': {'name': 'Archer Pull-up',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/BWArcherPullup',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'bodyweight': ['Archer Pull-up']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/BWUnderhandChinup': {'name': 'Chin-up',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/BWUnderhandChinup',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'bodyweight': ['Chin-up']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/BWOneArmPullup': {'name': 'One Arm Pull-up',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/BWOneArmPullup',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'bodyweight': ['One Arm Pull-up']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/BWCloseGripChinup': {'name': 'Parallel Close Grip Pull-up',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/BWCloseGripChinup',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'bodyweight': ['Parallel Close Grip Pull-up']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/BWPullup': {'name': 'Pull-up',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/BWPullup',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'bodyweight': ['Pull-up']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/AsUnderhandChinupSelf': {'name': 'Chin-up',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/AsUnderhandChinupSelf',
#   'implements': ['self-assisted'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'self-assisted': ['Chin-up']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/LatissimusDorsi/AsChinupSelf': {'name': 'Pull-up',
#   'exercise_url': 'https://exrx.net/WeightExercises/LatissimusDorsi/AsChinupSelf',
#   'implements': ['self-assisted'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'self-assisted': ['Pull-up']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/HipFlexors/BWKneelingWheelRollout': {'name': 'Wheel Rollout — Wheel Rollout',
#   'exercise_url': 'https://exrx.net/WeightExercises/HipFlexors/BWKneelingWheelRollout',
#   'implements': ['self-assisted'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'self-assisted': ['Wheel Rollout',
#     'Wheel Rollout — Wheel Rollout']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/Stretches/LatissimusDorsi/Bar': {'name': 'Bar — Bar',
#   'exercise_url': 'https://exrx.net/Stretches/LatissimusDorsi/Bar',
#   'implements': ['self-assisted'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'self-assisted': ['Bar', 'Bar — Bar']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/Stretches/LatissimusDorsi/PCUnderhand': {'name': 'Bar — Lever',
#   'exercise_url': 'https://exrx.net/Stretches/LatissimusDorsi/PCUnderhand',
#   'implements': ['self-assisted'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'self-assisted': ['Bar — Lever']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/Stretches/LatissimusDorsi/Overhead': {'name': 'Bar — Overhead',
#   'exercise_url': 'https://exrx.net/Stretches/LatissimusDorsi/Overhead',
#   'implements': ['self-assisted'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'self-assisted': ['Bar — Overhead']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/Stretches/LatissimusDorsi/Supine': {'name': 'Bar — Supine Lat',
#   'exercise_url': 'https://exrx.net/Stretches/LatissimusDorsi/Supine',
#   'implements': ['self-assisted'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'self-assisted': ['Bar — Supine Lat']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/Stretches/LatissimusDorsi/StandingSideReach': {'name': 'Bar — Standing Side Reach',
#   'exercise_url': 'https://exrx.net/Stretches/LatissimusDorsi/StandingSideReach',
#   'implements': ['self-assisted'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['General Back'],
#   'variants_by_impl': {'self-assisted': ['Bar — Standing Side Reach']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/TrapeziusUpper/BBShrug': {'name': 'Shrug',
#   'exercise_url': 'https://exrx.net/WeightExercises/TrapeziusUpper/BBShrug',
#   'implements': ['barbell'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Trapezius, Upper Fibers & Levator Scapulae'],
#   'variants_by_impl': {'barbell': ['Shrug']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/TrapeziusUpper/TBShrug': {'name': 'Trap Bar Shrug',
#   'exercise_url': 'https://exrx.net/WeightExercises/TrapeziusUpper/TBShrug',
#   'implements': ['barbell'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Trapezius, Upper Fibers & Levator Scapulae'],
#   'variants_by_impl': {'barbell': ['Trap Bar Shrug']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/TrapeziusUpper/CBShrug': {'name': 'Shrug',
#   'exercise_url': 'https://exrx.net/WeightExercises/TrapeziusUpper/CBShrug',
#   'implements': ['cable'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Trapezius, Upper Fibers & Levator Scapulae'],
#   'variants_by_impl': {'cable': ['Shrug']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/TrapeziusUpper/CBShrugStirrups': {'name': 'Shrug with stirrups',
#   'exercise_url': 'https://exrx.net/WeightExercises/TrapeziusUpper/CBShrugStirrups',
#   'implements': ['cable'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Trapezius, Upper Fibers & Levator Scapulae'],
#   'variants_by_impl': {'cable': ['Shrug with stirrups']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/TrapeziusUpper/DBShrug': {'name': 'Shrug',
#   'exercise_url': 'https://exrx.net/WeightExercises/TrapeziusUpper/DBShrug',
#   'implements': ['dumbbell'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Trapezius, Upper Fibers & Levator Scapulae'],
#   'variants_by_impl': {'dumbbell': ['Shrug']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/TrapeziusUpper/LVSeatedShrug': {'name': 'Seated Shrug',
#   'exercise_url': 'https://exrx.net/WeightExercises/TrapeziusUpper/LVSeatedShrug',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Trapezius, Upper Fibers & Levator Scapulae'],
#   'variants_by_impl': {'lever': ['Seated Shrug']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/TrapeziusUpper/LVShrugH': {'name': 'Shrug',
#   'exercise_url': 'https://exrx.net/WeightExercises/TrapeziusUpper/LVShrugH',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Trapezius, Upper Fibers & Levator Scapulae'],
#   'variants_by_impl': {'lever': ['Shrug']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/TrapeziusUpper/LVShrug': {'name': 'Shrug',
#   'exercise_url': 'https://exrx.net/WeightExercises/TrapeziusUpper/LVShrug',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Trapezius, Upper Fibers & Levator Scapulae'],
#   'variants_by_impl': {'lever': ['Shrug']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/TrapeziusUpper/SLXGripShrug': {'name': 'Gripless Shrug',
#   'exercise_url': 'https://exrx.net/WeightExercises/TrapeziusUpper/SLXGripShrug',
#   'implements': ['sled'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Trapezius, Upper Fibers & Levator Scapulae'],
#   'variants_by_impl': {'sled': ['Gripless Shrug']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/TrapeziusUpper/SMShrug': {'name': 'Shrug',
#   'exercise_url': 'https://exrx.net/WeightExercises/TrapeziusUpper/SMShrug',
#   'implements': ['smith machine'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Trapezius, Upper Fibers & Levator Scapulae'],
#   'variants_by_impl': {'smith machine': ['Shrug']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/TrapeziusUpper/BWInvertedShrugPB': {'name': 'Inverted Shrug',
#   'exercise_url': 'https://exrx.net/WeightExercises/TrapeziusUpper/BWInvertedShrugPB',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Trapezius, Upper Fibers & Levator Scapulae'],
#   'variants_by_impl': {'bodyweight': ['Inverted Shrug']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/TrapeziusUpper/BWInvertedShrugRings': {'name': 'Inverted Shrug',
#   'exercise_url': 'https://exrx.net/WeightExercises/TrapeziusUpper/BWInvertedShrugRings',
#   'implements': ['suspended'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Trapezius, Upper Fibers & Levator Scapulae'],
#   'variants_by_impl': {'suspended': ['Inverted Shrug']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/Stretches/TrapeziusUpper/Trap': {'name': 'Upper Trapezius',
#   'exercise_url': 'https://exrx.net/Stretches/TrapeziusUpper/Trap',
#   'implements': ['stretch'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Trapezius, Upper Fibers & Levator Scapulae'],
#   'variants_by_impl': {'stretch': ['Upper Trapezius']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/Stretches/Rhomboids/FixedBar': {'name': 'Fixed Bar',
#   'exercise_url': 'https://exrx.net/Stretches/Rhomboids/FixedBar',
#   'implements': ['stretch'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Rhomboids'],
#   'variants_by_impl': {'stretch': ['Fixed Bar']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/Stretches/Rhomboids/Hugging': {'name': 'Hugging',
#   'exercise_url': 'https://exrx.net/Stretches/Rhomboids/Hugging',
#   'implements': ['stretch'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Rhomboids'],
#   'variants_by_impl': {'stretch': ['Hugging']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/Infraspinatus/CBStandingExternalRotation': {'name': 'Standing Shoulder External Rotation',
#   'exercise_url': 'https://exrx.net/WeightExercises/Infraspinatus/CBStandingExternalRotation',
#   'implements': ['cable'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Rhomboids'],
#   'variants_by_impl': {'cable': ['Standing Shoulder External Rotation']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/Infraspinatus/DBLyingExternalRotation': {'name': 'Lying Shoulder External Rotation',
#   'exercise_url': 'https://exrx.net/WeightExercises/Infraspinatus/DBLyingExternalRotation',
#   'implements': ['dumbbell'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Rhomboids'],
#   'variants_by_impl': {'dumbbell': ['Lying Shoulder External Rotation']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/Infraspinatus/DBUprightExternalRotationSupport': {'name': 'Upright Shoulder External Rotation (with support)',
#   'exercise_url': 'https://exrx.net/WeightExercises/Infraspinatus/DBUprightExternalRotationSupport',
#   'implements': ['dumbbell'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Rhomboids'],
#   'variants_by_impl': {'dumbbell': ['Upright Shoulder External Rotation (with support)']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/Infraspinatus/LVShoulderExternalRotationPL': {'name': 'Shoulder External Rotation',
#   'exercise_url': 'https://exrx.net/WeightExercises/Infraspinatus/LVShoulderExternalRotationPL',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Rhomboids'],
#   'variants_by_impl': {'lever': ['Shoulder External Rotation']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/Infraspinatus/LVExternalRotation': {'name': 'Shoulder External Rotation',
#   'exercise_url': 'https://exrx.net/WeightExercises/Infraspinatus/LVExternalRotation',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Rhomboids'],
#   'variants_by_impl': {'lever': ['Shoulder External Rotation']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/Stretches/Infraspinatus/Broomstick': {'name': 'Broomstick',
#   'exercise_url': 'https://exrx.net/Stretches/Infraspinatus/Broomstick',
#   'implements': ['stretch'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Rhomboids'],
#   'variants_by_impl': {'stretch': ['Broomstick']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/Stretches/Infraspinatus/SideLying': {'name': 'Side Lying',
#   'exercise_url': 'https://exrx.net/Stretches/Infraspinatus/SideLying',
#   'implements': ['stretch'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Rhomboids'],
#   'variants_by_impl': {'stretch': ['Side Lying']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/Stretches/Infraspinatus/SideLyingTeresMinor': {'name': 'Side Lying Teres Minor',
#   'exercise_url': 'https://exrx.net/Stretches/Infraspinatus/SideLyingTeresMinor',
#   'implements': ['stretch'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Rhomboids'],
#   'variants_by_impl': {'stretch': ['Side Lying Teres Minor']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/Infraspinatus/STShoulderExternalRotation': {'name': 'Shoulder External Rotation',
#   'exercise_url': 'https://exrx.net/WeightExercises/Infraspinatus/STShoulderExternalRotation',
#   'implements': ['suspended'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Rhomboids'],
#   'variants_by_impl': {'suspended': ['Shoulder External Rotation']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/Subscapularis/CBStandingInternalRotation': {'name': 'Standing Shoulder Internal Rotation',
#   'exercise_url': 'https://exrx.net/WeightExercises/Subscapularis/CBStandingInternalRotation',
#   'implements': ['cable'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Rhomboids'],
#   'variants_by_impl': {'cable': ['Standing Shoulder Internal Rotation']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/Subscapularis/DBInternalRotationFloor': {'name': 'Shoulder Internal Rotation (on floor)',
#   'exercise_url': 'https://exrx.net/WeightExercises/Subscapularis/DBInternalRotationFloor',
#   'implements': ['dumbbell'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Rhomboids'],
#   'variants_by_impl': {'dumbbell': ['Shoulder Internal Rotation (on floor)']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/Subscapularis/LVShoulderInternalRotationPL': {'name': 'Shoulder Internal Rotation',
#   'exercise_url': 'https://exrx.net/WeightExercises/Subscapularis/LVShoulderInternalRotationPL',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Rhomboids'],
#   'variants_by_impl': {'lever': ['Shoulder Internal Rotation']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/Subscapularis/LVInternalRotation': {'name': 'Shoulder Internal Rotation',
#   'exercise_url': 'https://exrx.net/WeightExercises/Subscapularis/LVInternalRotation',
#   'implements': ['lever'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Rhomboids'],
#   'variants_by_impl': {'lever': ['Shoulder Internal Rotation']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/Stretches/Subscapularis/Broomstick': {'name': 'Broomstick',
#   'exercise_url': 'https://exrx.net/Stretches/Subscapularis/Broomstick',
#   'implements': ['stretch'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Rhomboids'],
#   'variants_by_impl': {'stretch': ['Broomstick']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/Stretches/Subscapularis/Doorway': {'name': 'Doorway',
#   'exercise_url': 'https://exrx.net/Stretches/Subscapularis/Doorway',
#   'implements': ['stretch'],
#   'macro_groups': ['Back'],
#   'micro_groups': ['Rhomboids'],
#   'variants_by_impl': {'stretch': ['Doorway']},
#   'list_urls': ['https://exrx.net/Lists/ExList/BackWt']},
#  'https://exrx.net/WeightExercises/Gastrocnemius/BBStandingCalfRaise': {'name': 'Standing Calf Raise',
#   'exercise_url': 'https://exrx.net/WeightExercises/Gastrocnemius/BBStandingCalfRaise',
#   'implements': ['barbell'],
#   'macro_groups': ['Calves'],
#   'micro_groups': ['General or Gastrocnemius'],
#   'variants_by_impl': {'barbell': ['Standing Calf Raise']},
#   'list_urls': ['https://exrx.net/Lists/ExList/CalfWt']},
#  'https://exrx.net/WeightExercises/Gastrocnemius/CBStandingCalfRaise': {'name': 'Belt Calf Raise',
#   'exercise_url': 'https://exrx.net/WeightExercises/Gastrocnemius/CBStandingCalfRaise',
#   'implements': ['cable'],
#   'macro_groups': ['Calves'],
#   'micro_groups': ['General or Gastrocnemius'],
#   'variants_by_impl': {'cable': ['Belt Calf Raise']},
#   'list_urls': ['https://exrx.net/Lists/ExList/CalfWt']},
#  'https://exrx.net/WeightExercises/Gastrocnemius/CBOneArmSingleLegCalfRaise': {'name': 'One Arm Single Leg Calf Raise',
#   'exercise_url': 'https://exrx.net/WeightExercises/Gastrocnemius/CBOneArmSingleLegCalfRaise',
#   'implements': ['cable'],
#   'macro_groups': ['Calves'],
#   'micro_groups': ['General or Gastrocnemius'],
#   'variants_by_impl': {'cable': ['One Arm Single Leg Calf Raise']},
#   'list_urls': ['https://exrx.net/Lists/ExList/CalfWt']},
#  'https://exrx.net/WeightExercises/Gastrocnemius/DBStandingCalfRaise': {'name': 'Standing Calf Raise',
#   'exercise_url': 'https://exrx.net/WeightExercises/Gastrocnemius/DBStandingCalfRaise',
#   'implements': ['dumbbell'],
#   'macro_groups': ['Calves'],
#   'micro_groups': ['General or Gastrocnemius'],
#   'variants_by_impl': {'dumbbell': ['Standing Calf Raise']},
#   'list_urls': ['https://exrx.net/Lists/ExList/CalfWt']},
#  'https://exrx.net/WeightExercises/Gastrocnemius/DBSingleLegCalfRaise': {'name': 'Standing Calf Raise — Single Leg',
#   'exercise_url': 'https://exrx.net/WeightExercises/Gastrocnemius/DBSingleLegCalfRaise',
#   'implements': ['dumbbell'],
#   'macro_groups': ['Calves'],
#   'micro_groups': ['General or Gastrocnemius'],
#   'variants_by_impl': {'dumbbell': ['Standing Calf Raise — Single Leg']},
#   'list_urls': ['https://exrx.net/Lists/ExList/CalfWt']},
#  'https://exrx.net/WeightExercises/Gastrocnemius/LV45CalfPress': {'name': '45° Calf Press',
#   'exercise_url': 'https://exrx.net/WeightExercises/Gastrocnemius/LV45CalfPress',
#   'implements': ['lever'],
#   'macro_groups': ['Calves'],
#   'micro_groups': ['General or Gastrocnemius'],
#   'variants_by_impl': {'lever': ['45° Calf Press']},
#   'list_urls': ['https://exrx.net/Lists/ExList/CalfWt']},
#  'https://exrx.net/WeightExercises/Gastrocnemius/LVSeatedCalfExtensionHammer': {'name': 'Calf Extension',
#   'exercise_url': 'https://exrx.net/WeightExercises/Gastrocnemius/LVSeatedCalfExtensionHammer',
#   'implements': ['lever'],
#   'macro_groups': ['Calves'],
#   'micro_groups': ['General or Gastrocnemius'],
#   'variants_by_impl': {'lever': ['Calf Extension']},
#   'list_urls': ['https://exrx.net/Lists/ExList/CalfWt']},
#  'https://exrx.net/WeightExercises/Gastrocnemius/LVSeatedCalfPressH': {'name': 'Seated Calf Press',
#   'exercise_url': 'https://exrx.net/WeightExercises/Gastrocnemius/LVSeatedCalfPressH',
#   'implements': ['lever'],
#   'macro_groups': ['Calves'],
#   'micro_groups': ['General or Gastrocnemius'],
#   'variants_by_impl': {'lever': ['Seated Calf Press']},
#   'list_urls': ['https://exrx.net/Lists/ExList/CalfWt']},
#  'https://exrx.net/WeightExercises/Gastrocnemius/LVStandingCalfRaisePL': {'name': 'Standing Calf Raise',
#   'exercise_url': 'https://exrx.net/WeightExercises/Gastrocnemius/LVStandingCalfRaisePL',
#   'implements': ['lever'],
#   'macro_groups': ['Calves'],
#   'micro_groups': ['General or Gastrocnemius'],
#   'variants_by_impl': {'lever': ['Standing Calf Raise']},
#   'list_urls': ['https://exrx.net/Lists/ExList/CalfWt']},
#  'https://exrx.net/WeightExercises/Gastrocnemius/LV45CalfRaise': {'name': '45° Calf Raise',
#   'exercise_url': 'https://exrx.net/WeightExercises/Gastrocnemius/LV45CalfRaise',
#   'implements': ['lever'],
#   'macro_groups': ['Calves'],
#   'micro_groups': ['General or Gastrocnemius'],
#   'variants_by_impl': {'lever': ['45° Calf Raise']},
#   'list_urls': ['https://exrx.net/Lists/ExList/CalfWt']},
#  'https://exrx.net/WeightExercises/Gastrocnemius/LVSeatedCalfExtension': {'name': 'Calf Extension',
#   'exercise_url': 'https://exrx.net/WeightExercises/Gastrocnemius/LVSeatedCalfExtension',
#   'implements': ['lever'],
#   'macro_groups': ['Calves'],
#   'micro_groups': ['General or Gastrocnemius'],
#   'variants_by_impl': {'lever': ['Calf Extension']},
#   'list_urls': ['https://exrx.net/Lists/ExList/CalfWt']},
#  'https://exrx.net/WeightExercises/Gastrocnemius/LVDonkeyCalfRaise': {'name': 'Donkey Calf Raise',
#   'exercise_url': 'https://exrx.net/WeightExercises/Gastrocnemius/LVDonkeyCalfRaise',
#   'implements': ['lever'],
#   'macro_groups': ['Calves'],
#   'micro_groups': ['General or Gastrocnemius'],
#   'variants_by_impl': {'lever': ['Donkey Calf Raise']},
#   'list_urls': ['https://exrx.net/Lists/ExList/CalfWt']},
#  'https://exrx.net/WeightExercises/Gastrocnemius/LVSeatedCalfPress': {'name': 'Seated Calf Press',
#   'exercise_url': 'https://exrx.net/WeightExercises/Gastrocnemius/LVSeatedCalfPress',
#   'implements': ['lever'],
#   'macro_groups': ['Calves'],
#   'micro_groups': ['General or Gastrocnemius'],
#   'variants_by_impl': {'lever': ['Seated Calf Press']},
#   'list_urls': ['https://exrx.net/Lists/ExList/CalfWt']},
#  'https://exrx.net/WeightExercises/Gastrocnemius/LVStandingCalfRaise': {'name': 'Standing Calf Raise',
#   'exercise_url': 'https://exrx.net/WeightExercises/Gastrocnemius/LVStandingCalfRaise',
#   'implements': ['lever'],
#   'macro_groups': ['Calves'],
#   'micro_groups': ['General or Gastrocnemius'],
#   'variants_by_impl': {'lever': ['Standing Calf Raise']},
#   'list_urls': ['https://exrx.net/Lists/ExList/CalfWt']},
#  'https://exrx.net/WeightExercises/Gastrocnemius/SL45CalfPress': {'name': '45° Calf Press',
#   'exercise_url': 'https://exrx.net/WeightExercises/Gastrocnemius/SL45CalfPress',
#   'implements': ['sled'],
#   'macro_groups': ['Calves'],
#   'micro_groups': ['General or Gastrocnemius'],
#   'variants_by_impl': {'sled': ['45° Calf Press']},
#   'list_urls': ['https://exrx.net/Lists/ExList/CalfWt']},
#  'https://exrx.net/WeightExercises/Gastrocnemius/SL45CalfRaise': {'name': '45° Calf Raise',
#   'exercise_url': 'https://exrx.net/WeightExercises/Gastrocnemius/SL45CalfRaise',
#   'implements': ['sled'],
#   'macro_groups': ['Calves'],
#   'micro_groups': ['General or Gastrocnemius'],
# ...
#   'exercise_url': 'https://exrx.net/WeightExercises/Obliques/BWInclineTwistingSitUpX',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Obliques'],
#   'variants_by_impl': {'bodyweight': ['Incline Twisting Sit-up — Incline Twisting Sit-up — arms crossed']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/Obliques/BWTwistingSitUp': {'name': 'Incline Twisting Sit-up — Twisting Sit-up',
#   'exercise_url': 'https://exrx.net/WeightExercises/Obliques/BWTwistingSitUp',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Obliques'],
#   'variants_by_impl': {'bodyweight': ['Incline Twisting Sit-up — Twisting Sit-up']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/Obliques/BWTwistingSitUpX': {'name': 'Incline Twisting Sit-up — Twisting Sit-up — arms crossed',
#   'exercise_url': 'https://exrx.net/WeightExercises/Obliques/BWTwistingSitUpX',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Obliques'],
#   'variants_by_impl': {'bodyweight': ['Incline Twisting Sit-up — Twisting Sit-up — arms crossed']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/Obliques/BWInclineTwistingCrunch': {'name': 'Incline Twisting Crunch — Incline Twisting Crunch',
#   'exercise_url': 'https://exrx.net/WeightExercises/Obliques/BWInclineTwistingCrunch',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Obliques'],
#   'variants_by_impl': {'bodyweight': ['Incline Twisting Crunch',
#     'Incline Twisting Crunch — Incline Twisting Crunch']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/Obliques/BWInclineTwistingCrunchX': {'name': 'Incline Twisting Crunch — Incline Twisting Crunch — arms crossed',
#   'exercise_url': 'https://exrx.net/WeightExercises/Obliques/BWInclineTwistingCrunchX',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Obliques'],
#   'variants_by_impl': {'bodyweight': ['Incline Twisting Crunch — Incline Twisting Crunch — arms crossed']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/Obliques/BWSideCrunch': {'name': 'Incline Twisting Crunch — Side Crunch',
#   'exercise_url': 'https://exrx.net/WeightExercises/Obliques/BWSideCrunch',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Obliques'],
#   'variants_by_impl': {'bodyweight': ['Incline Twisting Crunch — Side Crunch']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/Obliques/BWTwistingCrunch': {'name': 'Incline Twisting Crunch — Twisting Crunch',
#   'exercise_url': 'https://exrx.net/WeightExercises/Obliques/BWTwistingCrunch',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Obliques'],
#   'variants_by_impl': {'bodyweight': ['Incline Twisting Crunch — Twisting Crunch']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/Obliques/BWTwistingCrunchX': {'name': 'Incline Twisting Crunch — Twisting Crunch — arms crossed',
#   'exercise_url': 'https://exrx.net/WeightExercises/Obliques/BWTwistingCrunchX',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Obliques'],
#   'variants_by_impl': {'bodyweight': ['Incline Twisting Crunch — Twisting Crunch — arms crossed']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/Obliques/BWTwistingBallCrunch': {'name': 'Incline Twisting Crunch — Twisting Crunch — on ball',
#   'exercise_url': 'https://exrx.net/WeightExercises/Obliques/BWTwistingBallCrunch',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Obliques'],
#   'variants_by_impl': {'bodyweight': ['Incline Twisting Crunch — Twisting Crunch — on ball']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/Obliques/STTwistingJackknife': {'name': 'Twisting Jack-knife',
#   'exercise_url': 'https://exrx.net/WeightExercises/Obliques/STTwistingJackknife',
#   'implements': ['suspended'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Obliques'],
#   'variants_by_impl': {'suspended': ['Twisting Jack-knife']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/Stretches/Obliques/LyingCrossover': {'name': 'Lying Crossover',
#   'exercise_url': 'https://exrx.net/Stretches/Obliques/LyingCrossover',
#   'implements': ['stretch'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Obliques'],
#   'variants_by_impl': {'stretch': ['Lying Crossover']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/Stretches/Obliques/Pretzel': {'name': 'Pretzel',
#   'exercise_url': 'https://exrx.net/Stretches/Obliques/Pretzel',
#   'implements': ['stretch'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Obliques'],
#   'variants_by_impl': {'stretch': ['Pretzel']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/BBHyperextension': {'name': 'Hyperextension',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/BBHyperextension',
#   'implements': ['barbell'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'barbell': ['Hyperextension']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/BB45Hyperextension': {'name': 'Hyperextension (45°)',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/BB45Hyperextension',
#   'implements': ['barbell'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'barbell': ['Hyperextension (45°)']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/BBBentKneeGoodMorning': {'name': 'Bent Knee Good-morning',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/BBBentKneeGoodMorning',
#   'implements': ['barbell'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'barbell': ['Bent Knee Good-morning']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/BBDeadlift': {'name': 'Deadlift',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/BBDeadlift',
#   'implements': ['barbell'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'barbell': ['Deadlift']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/BBStiffLegDeadlift': {'name': 'Deadlift — Stiff-leg Deadlift',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/BBStiffLegDeadlift',
#   'implements': ['barbell'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'barbell': ['Deadlift — Stiff-leg Deadlift']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/BBStraightLegDeadlift': {'name': 'Deadlift — Straight-leg Deadlift',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/BBStraightLegDeadlift',
#   'implements': ['barbell'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'barbell': ['Deadlift — Straight-leg Deadlift']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/CBStiffLegDeadlift': {'name': 'Stiff-leg Deadlift',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/CBStiffLegDeadlift',
#   'implements': ['cable'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'cable': ['Stiff-leg Deadlift']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/LVDeadlift': {'name': 'Deadlift',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/LVDeadlift',
#   'implements': ['lever'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'lever': ['Deadlift']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/LVStiffLegDeadlift': {'name': 'Stiff-leg Deadlift',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/LVStiffLegDeadlift',
#   'implements': ['lever'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'lever': ['Stiff-leg Deadlift']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/LVBackExtensionN': {'name': 'Back Extension',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/LVBackExtensionN',
#   'implements': ['lever'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'lever': ['Back Extension']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/LVBackExtension': {'name': 'Back Extension — on older machine',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/LVBackExtension',
#   'implements': ['lever'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'lever': ['Back Extension — on older machine']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/SMBentKneeGoodMorning': {'name': 'Bent Knee Good-morning',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/SMBentKneeGoodMorning',
#   'implements': ['smith machine'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'smith machine': ['Bent Knee Good-morning']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/SMDeadlift': {'name': 'Deadlift',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/SMDeadlift',
#   'implements': ['smith machine'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'smith machine': ['Deadlift']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/SMStiffLegDeadlift': {'name': 'Stiff-leg Deadlift',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/SMStiffLegDeadlift',
#   'implements': ['smith machine'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'smith machine': ['Stiff-leg Deadlift']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/BWHyperextensionBall': {'name': 'Back Extension (on ball)',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/BWHyperextensionBall',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'bodyweight': ['Back Extension (on ball)']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/BWBirdDog': {'name': 'Bird Dog',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/BWBirdDog',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'bodyweight': ['Bird Dog']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/BWAlternatingBirdDog': {'name': 'Bird Dog — Alternating',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/BWAlternatingBirdDog',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'bodyweight': ['Bird Dog — Alternating']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/BW45HyperextensionHips': {'name': 'Hyperextension (45°)',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/BW45HyperextensionHips',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'bodyweight': ['Hyperextension (45°)']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/BW45HyperextensionArmsCrossed': {'name': 'Hyperextension (45°) — arms crossed',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/BW45HyperextensionArmsCrossed',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'bodyweight': ['Hyperextension (45°) — arms crossed']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/BW45HyperextensionNeck': {'name': 'Hyperextension (45°) — hands behind neck',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/BW45HyperextensionNeck',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'bodyweight': ['Hyperextension (45°) — hands behind neck']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/BW45HyperextensionArmsUp': {'name': 'Hyperextension (45°) — arms up',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/BW45HyperextensionArmsUp',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'bodyweight': ['Hyperextension (45°) — arms up']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/Superman': {'name': 'Superman',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/Superman',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'bodyweight': ['Superman']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/ContraLateralSuperman': {'name': 'Superman — Contralateral',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/ContraLateralSuperman',
#   'implements': ['bodyweight'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'bodyweight': ['Superman — Contralateral']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/WeightExercises/ErectorSpinae/STPullThrough': {'name': 'Pull Through',
#   'exercise_url': 'https://exrx.net/WeightExercises/ErectorSpinae/STPullThrough',
#   'implements': ['suspended'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'suspended': ['Pull Through']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/Stretches/ErectorSpinae/Cat': {'name': 'Cat',
#   'exercise_url': 'https://exrx.net/Stretches/ErectorSpinae/Cat',
#   'implements': ['stretch'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'stretch': ['Cat']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/Stretches/ErectorSpinae/Lying': {'name': 'Lying',
#   'exercise_url': 'https://exrx.net/Stretches/ErectorSpinae/Lying',
#   'implements': ['stretch'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'stretch': ['Lying']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']},
#  'https://exrx.net/Stretches/ErectorSpinae/SeatedFloor': {'name': 'Seated',
#   'exercise_url': 'https://exrx.net/Stretches/ErectorSpinae/SeatedFloor',
#   'implements': ['stretch'],
#   'macro_groups': ['Waist'],
#   'micro_groups': ['Erector Spinae'],
#   'variants_by_impl': {'stretch': ['Seated']},
#   'list_urls': ['https://exrx.net/Lists/ExList/WaistWt']}}

# %%
import re, hashlib
from urllib.parse import urlparse

def exrx_canonical_key(ex_url: str):
    """
    Ritorna ('WeightExercises', slug) per gli esercizi, altrimenti (first_path, slug).
    Esempio: https://exrx.net/WeightExercises/GluteusMaximus/BWSquat -> ('WeightExercises','BWSquat')
    """
    p = urlparse(ex_url)
    parts = [x for x in p.path.split("/") if x]
    if not parts:
        return None
    slug = parts[-1]
    first = parts[0]
    return (first, slug)

def merge_docs(a: dict, b: dict) -> dict:
    """Unisci due entry dello stesso esercizio."""
    out = dict(a)
    # name: tieni il più ricco
    if len(b.get("name","")) > len(out.get("name","")):
        out["name"] = b["name"]

    # fields set-like
    for k in ("implements","macro_groups","micro_groups","list_urls"):
        sa = set(out.get(k, []))
        sb = set(b.get(k, []))
        out[k] = sorted(sa | sb)

    # variants_by_impl: unione per implement
    vbi_a = out.get("variants_by_impl", {})
    vbi_b = b.get("variants_by_impl", {})
    merged = {}
    for impl in set(vbi_a.keys()) | set(vbi_b.keys()):
        merged[impl] = sorted(set(vbi_a.get(impl, [])) | set(vbi_b.get(impl, [])))
    out["variants_by_impl"] = merged

    return out

# %%
def dedupe_by_slug(catalog: dict) -> dict:
    """
    Collassa il catalog per chiave canonica ('WeightExercises', slug).
    Restituisce un nuovo dict indicizzato dalla *chiave canonica* (non più dall'URL singolo).
    """
    buckets = {}
    url_index = {}  # mappa canon_key -> lista URL originali (utile per trace)

    for url, doc in catalog.items():
        key = exrx_canonical_key(url)
        if key is None:
            # tieni a parte (se hai altre sezioni oltre WeightExercises)
            key = ("other", url.rsplit("/",1)[-1])
        if key not in buckets:
            buckets[key] = {
                **doc,
                "exercise_url": url,      # tieni uno come "preferito"
                "_all_urls": [url],       # traccia tutti gli URL uniti
            }
            url_index[key] = [url]
        else:
            buckets[key] = merge_docs(buckets[key], doc)
            url_index[key].append(url)
            buckets[key]["_all_urls"] = sorted(set(buckets[key].get("_all_urls", []) + [url]))

    return buckets

dedup = dedupe_by_slug(catalog)
print("Prima:", len(catalog), "→ Dopo (per slug):", len(dedup))
# Esempio: cerca BWSquat
for k, d in dedup.items():
    if k[1].lower() == "bwsquat":
        print("\nChiave canonica:", k)
        print("URL preferito:  ", d["exercise_url"])
        print("Tutti gli URL:  ", d["_all_urls"])
        print("Macro groups:   ", d["macro_groups"])
        print("Micro groups:   ", d["micro_groups"])
        print("Implements:     ", d["implements"])
        print("Name:           ", d["name"])
        break
# Out:
# Prima: 745 → Dopo (per slug): 653
#
# Chiave canonica: ('WeightExercises', 'BWSquat')
# URL preferito:   https://exrx.net/WeightExercises/GluteusMaximus/BWSquat
# Tutti gli URL:   ['https://exrx.net/WeightExercises/GluteusMaximus/BWSquat', 'https://exrx.net/WeightExercises/Quadriceps/BWSquat']
# Macro groups:    ['Hips', 'Thighs']
# Micro groups:    ['Gluteus Maximus', 'Quadriceps']
# Implements:      ['bodyweight']
# Name:            Squat
